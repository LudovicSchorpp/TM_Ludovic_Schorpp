# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = "../../data/prélèvements/donnees_sandra/SynthèseSLanini_data_Prelevements_1987-2018.xlsx"
a = pd.read_excel(data,header=2)

# %%
fig,ax = plt.subplots(figsize=(15,7))
B = a.groupby(["USAGES"]).sum().loc[:,"VOL_1987":"VOL_2018"]
B.drop(B.index[B.sum(1) == 0]).plot(kind="bar",ax=ax,legend=[],title=("Prélèvements par usage"))
plt.ylabel("Volumes annuels [m$^3$]")
# Out:
# Text(0, 0.5, 'Volumes annuels [m$^3$]')

# %%
fig = plt.figure(figsize=(12,6))
a.iloc[:,8:40].sum().plot(kind="bar")
plt.title("Prélèvements totaux par année")
plt.xlabel("Annee")
plt.ylabel("Volume annuel [m$^3$]")
# Out:
# Text(0, 0.5, 'Volume annuel [m$^3$]')
