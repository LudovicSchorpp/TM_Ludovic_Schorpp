# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp

# %%
import codecs

file = "../../data/chroniques/chroniquesADES_Multicouche pliocène du Roussillon(DG243).txt"

with codecs.open(file, 'r', encoding='utf-8',
                 errors='ignore') as fdata:
    a = pd.read_csv(fdata,sep="|")

# %%
a["Date de la mesure"]=pd.to_datetime(a["Date de la mesure"])

# %%
a.set_index(["Date de la mesure"],inplace=True)
a.sort_index(inplace=True)

# %%
a.groupby(["Code national BSS"])["Cte NGF"].plot()
plt.legend()

# %%
x=a.X_WGS84.unique()
y=a.Y_WGS84.unique()

# %%
inproj = Proj(init="epsg:4326")
outproj = Proj(init="epsg:2154")
x1,x2,x3 = x
y1,y2,y3 = y
xp,yp = transform(inproj,outproj,x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-c645bec50eea> in <module>
#       1 inproj = Proj(init="epsg:4326")
#       2 outproj = Proj(init="epsg:2154")
# ----> 3 x1,x2,x3 = x
#       4 y1,y2,y3 = y
#       5 xp,yp = transform(inproj,outproj,x,y)
#
# ValueError: too many values to unpack (expected 3)

# %%
def coor_convert(x,y,epsgin,epsgout):
    from pyproj import Proj, transform
    inproj = Proj(init="epsg:{}".format(epsgin))
    outproj = Proj(init="epsg:{}".format(epsgout))
    xp,yp = transform(inproj,outproj,x,y)
    return xp,yp

# %%
a["X_L93"]=coor_convert(a.X_WGS84.values,a.Y_WGS84.values,"4326","2154")[0]
a["Y_L93"]=coor_convert(a.X_WGS84.values,a.Y_WGS84.values,"4326","2154")[1]

# %%
fig, ax = plt.subplots(figsize=(15,7))

for i in range(a["Code national BSS"].unique().shape[0]):
    ax.plot(a[a["Code national BSS"]==a["Code national BSS"].unique()[i]]["Cte NGF"],"-*",label=a["Code national BSS"].unique()[i])
    ax.legend()

# %%
data=pd.DataFrame(a.groupby(["Code national BSS"])["Cte NGF"].mean())

# %%
data["X"]=a.groupby(["Code national BSS"])["X_L93"].mean()
data["Y"]=a.groupby(["Code national BSS"])["Y_L93"].mean()
data.drop("10911X0137/F2",inplace=True)
