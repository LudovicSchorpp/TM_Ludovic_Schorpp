# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import flopy
from flopy.utils import Raster
# Out:
# flopy is installed in C:\Users\schorppl\AppData\Local\Continuum\anaconda3\lib\site-packages\flopy

# %%
path_plio = "../data/T&K/TPlio_mai2018_RGF93_L93_emprise.tif"
path_Q = "../data/T&K/TQuat_mai2018_RGF93_L93_emprise.tif"


arr = Raster.load(path_plio).get_array(1)
arr [arr == 0]= None

fig = plt.figure(figsize=(15,12))
plt.imshow(np.log10(arr),extent = [664525.0, 704e3,6152875.0,619.5e4])
plt.grid()
plt.colorbar()
plt.title("Carte T Pliocène")
# Out:
# Text(0.5, 1.0, 'Carte T Pliocène')

# %%
arr = Raster.load(path_Q).get_array(1)
arr [arr == 0]= None

fig = plt.figure(figsize=(15,12))
plt.imshow(np.log10(arr),extent = [664525.0, 704e3,6152875.0,619.5e4])
plt.grid()
plt.colorbar()
plt.title("Carte T Quaternaire")
# Out:
# Text(0.5, 1.0, 'Carte T Quaternaire')
