# %%
import pandas as pd
import geopandas as gp
from shapely.geometry import *
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import flopy as fp
from flopy.utils.gridintersect import GridIntersect
from flopy.utils import Raster
import rasterio
# Out:
# flopy is installed in C:\Users\schorppl\AppData\Local\Continuum\anaconda3\lib\site-packages\flopy

# %%
def resample_rast(rast_path,grid,band=1):
    arr = Raster.load(rast_path)
    arr = arr.resample_to_grid(grid.xcellcenters,grid.ycellcenters,band)
    return arr

# %%
# extract boundaries data from surfaces
MNT_path = "../../data/surfaces_geoter_decoup/TOPO (inf 0 en mer).asc"
x0,y0,x1,y1 = rasterio.open(MNT_path).bounds
x1 -= 3e4
# set resolution of the array
res = 50
Lx = x1-x0
Ly = y1-y0
nrow = int(Ly/res)
ncol = int(Lx/res)

#create grid with flopy
grid = fp.discretization.StructuredGrid(delc=res*np.ones([nrow]),delr=res*np.ones([ncol]),xoff=x0,yoff=y0)
ix = GridIntersect(grid)

# %%
shp = "zones_irrigation/zCan.shp" # a shp polygon near Canet where irrigation is only provided by wells
parcelles = "parcelles/Parcelles.shp" # a shp with mulitple polygons, one per culture on the plain
zones_irr = "zones_irrigation/Zirr_mod.shp" #list of irrigation zones made by Brli

# %%
#load shp
parc = gp.read_file(parcelles)
zCan = gp.read_file(shp)
zIrr = gp.read_file(zones_irr)

#append the polygon from Canet

zCan["Surf_Z_Ha"] = zCan.geometry[0].area/1e4 #get area
zCan["Irr_forage"] = 1 # add info about irrgation source
zCan["X_p"] = 0.1

zIrr = zIrr.append(zCan,sort=False).reset_index(drop=True)

# ajout d'une colonne pour l'irrigation par canaux
zIrr["Irr_can"] = 1-zIrr["Irr_forage"]
zIrr.loc[zIrr["Zones"]=="Zone 4","Irr_can"]=0

# %%
zIrr
# Out:
#      Id       Zones                                              Types  \
# 0   0.0      Zone 7    Irrigation par canaux du bassin du Tech (100 %)
# 1   0.0      Zone 8  Irrigation mixte : Canaux _ Tech (20 %) / Fora...
# 2   0.0      Zone 7    Irrigation par canaux du bassin du Tech (100 %)
# 3   0.0      Zone 4  Irrigation sous pression par VdR (30 %) / Fora...
# 4   0.0     Zone 2B  Irrigation mixte : Canaux de la TÃÂªt (70 %) ...
# 5   0.0     Zone 3B  Irrigation mixte : Canaux _ TÃªt  (Transfert h...
# 6   0.0      Zone 3  Irrigation mixte : Canaux _ TÃªt / Forages (> ...
# 7   0.0      Zone 3  Irrigation mixte : Canaux _ TÃªt / Forages (> ...
# 8   0.0      Zone 3  Irrigation mixte : Canaux _ TÃªt / Forages (> ...
# 9   0.0      Zone 6  Irrigation mixte : Canaux_ Agly (< 20 %) / For...
# 10  0.0      Zone 6  Irrigation mixte : Canaux_ Agly (< 20 %) / For...
# 11  0.0      Zone 5  Irrigation par canaux du bassin de l'Agly (100 %)
# 12  0.0      Zone 6  Irrigation mixte : Canaux_ Agly (< 20 %) / For...
# 13  0.0      Zone 9  Irrigation mixte : Canaux _ TÃªt / Forages (Si...
# 14  0.0     Zone 2A  Irrigation mixte : Canaux de la TÃÂªt (95 %) ...
# 15  NaN    Zone Rea                                               None
# 16  NaN  Villeneuve                                               None
# 17  NaN       Tech3                                               None
# 18  NaN       Rear3                                               None
# 19  NaN        Rea2                                               None
# 20  NaN  Zone_Canet                                                NaN
#
#       Surf_Z_Ha                                          Etiquette  ZC  \
# 0   1235.030000  Zone 7 : Irrigation par canaux du bassin du Te...   2
# 1   1694.310000  Zone 8 : Irrigation mixte : Canaux _ Tech (20 ...   3
# 2   1227.440000  Zone 7 : Irrigation par canaux du bassin du Te...   2
# 3   7033.390000  Zone 4 : Irrigation sous pression par VdR (30 ...   3
# 4    799.450000  Zone 2B : Irrigation mixte : Canaux de la TÃÂ...   3
# 5    410.770000  Zone 3B : Irrigation mixte : Canaux _ TÃªt  (T...   3
# 6    402.030000  Zone 3 : Irrigation mixte : Canaux _ TÃªt / Fo...   3
# 7   1766.310000  Zone 3 : Irrigation mixte : Canaux _ TÃªt / Fo...   3
# 8   5964.980000  Zone 3 : Irrigation mixte : Canaux _ TÃªt / Fo...   2
# 9    233.280000  Zone 6 : Irrigation mixte : Canaux_ Agly (< 20...   3
# 10    69.570000  Zone 6 : Irrigation mixte : Canaux_ Agly (< 20...   3
# 11   273.920000  Zone 5 : Irrigation par canaux du bassin de l'...   3
# 12   238.300000  Zone 6 : Irrigation mixte : Canaux_ Agly (< 20...   3
# 13   267.490000  Zone 9 : Irrigation mixte : Canaux _ TÃªt / Fo...   1
# 14  1070.870000  Zone 2A : Irrigation mixte : Canaux de la TÃÂ...   1
# 15   767.140000                                               None   3
# 16   496.120000                                               None   3
# 17   225.060000                                               None   3
# 18   581.410000                                               None   3
# 19   511.300000                                               None   3
# 20  9038.624153                                                NaN   3
#
#     Irr_forage   X_p                                           geometry  \
# 0         0.00  0.36  POLYGON ((689548.932 6159779.286, 689330.629 6...
# 1         0.80  0.32  POLYGON ((702638.710 6164713.007, 702702.478 6...
# 2         0.00  0.00  MULTIPOLYGON (((683722.928 6156383.584, 683813...
# 3         0.70  0.50  POLYGON ((700069.343 6173529.460, 701428.421 6...
# 4         0.30  0.40  POLYGON ((678247.347 6173329.417, 678248.682 6...
# 5         0.75  0.23  POLYGON ((691908.474 6179742.319, 691911.937 6...
# 6         0.75  0.20  POLYGON ((692589.108 6178710.935, 693491.651 6...
# 7         0.75  0.40  POLYGON ((681182.001 6177675.798, 681201.069 6...
# 8         0.75  0.40  POLYGON ((673869.847 6177678.511, 673893.666 6...
# 9         0.80  0.23  POLYGON ((694653.450 6185424.447, 694630.271 6...
# 10        0.80  0.23  POLYGON ((696117.660 6183683.036, 696166.229 6...
# 11        0.00  0.23  POLYGON ((687062.065 6185375.996, 687145.561 6...
# 12        0.80  0.23  POLYGON ((687419.911 6185886.348, 687373.275 6...
# 13        0.30  0.40  POLYGON ((665087.911 6173464.872, 665059.118 6...
# 14        0.05  0.40  POLYGON ((675039.198 6174802.025, 675030.185 6...
# 15        1.00  1.00  POLYGON ((682924.314 6165679.201, 684481.057 6...
# 16        1.00  1.00  POLYGON ((689622.225 6166337.178, 689407.582 6...
# 17        1.00  0.28  POLYGON ((697963.012 6162165.097, 698171.928 6...
# 18        1.00  0.28  POLYGON ((697149.730 6173312.273, 697163.099 6...
# 19        1.00  1.00  POLYGON ((682524.036 6171173.368, 682782.694 6...
# 20        1.00  0.10  MULTIPOLYGON (((696237.446 6195219.837, 696238...
#
#     Irr_can
# 0      1.00
# 1      0.20
# 2      1.00
# 3      0.00
# 4      0.70
# 5      0.25
# 6      0.25
# 7      0.25
# 8      0.25
# 9      0.20
# 10     0.20
# 11     1.00
# 12     0.20
# 13     0.70
# 14     0.95
# 15     0.00
# 16     0.00
# 17     0.00
# 18     0.00
# 19     0.00
# 20     0.00

# %%
#calculate area per culture type and by zones
surf=[]

## calculate surface for each culture
for zi in range(zIrr.shape[0]):
    mask=[]
    for p in range(parc.shape[0]):
        mask.append(zIrr.geometry[zi].intersects(parc.geometry[p]))
    df = parc.loc[mask].groupby(["Name"]).sum()["Surf_P_Ha"]
    
    surf_mar=0
    surf_verg=0
    for i in range(df.shape[0]):
        if df.index[i] == "Verger":
            surf_verg = df.values[i]
        if df.index[i] == 'Maraichage':
            surf_mar = df.values[i]
                    
    surf.append((zIrr.loc[zi,"Zones"],surf_mar,surf_verg))

# %%
surf = pd.DataFrame(surf,columns=["Zones","area_maraichage [Ha]","area_verger [Ha]"])

# %% [markdown]
# - maraichage 90 % d'hiver 10 % d'été
# - verger 30 % abricots et 70 % pêchers

# %%
mara_e = np.array([353,417,494])
mara_h = np.array([25,46,60])
abr = np.array([144,190,252])
pech = np.array([458,545,648])

# %%
verger = 0.3*abr+0.7*pech
mara = 0.9*mara_h+0.1*mara_e

# facteur besoins
z=3
besoins = np.ones([zIrr.shape[0],2])
for i,z in enumerate(zIrr["ZC"]):
    besoins[int(i)] = [mara[z-1],verger[z-1]]

W_need = surf.set_index("Zones")*10*besoins
W_need.columns = ["w_need_mar [m$^3$]","w_need_verg [m$^3$]"]

# %%
cm = sns.light_palette("blue", as_cmap=True)
W_need.reset_index().style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow0_col1 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow0_col2 {
#             background-color:  #c2c2ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow1_col1 {
#             background-color:  #c6c6ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow1_col2 {
#             background-color:  #c4c4ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow2_col2 {
#             background-color:  #dedeff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow3_col1 {
#             background-color:  #4646ff;
#             color:  #f1f1f1;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow3_col2 {
#             background-color:  #a5a5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow4_col1 {
#             background-color:  #dedeff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow4_col2 {
#             background-color:  #9696ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow5_col1 {
#             background-color:  #ddddff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow5_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow6_col1 {
#             background-color:  #bdbdff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow6_col2 {
#             background-color:  #dfdfff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow7_col1 {
#             background-color:  #c3c3ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow7_col2 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow8_col1 {
#             background-color:  #c3c3ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow8_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow9_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow9_col2 {
#             background-color:  #d6d6ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow10_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow10_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow11_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow11_col2 {
#             background-color:  #ddddff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow12_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow12_col2 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow13_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow13_col2 {
#             background-color:  #e1e1ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow14_col1 {
#             background-color:  #e2e2ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow14_col2 {
#             background-color:  #9a9aff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow15_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow15_col2 {
#             background-color:  #c9c9ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow16_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow16_col2 {
#             background-color:  #dfdfff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow17_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow17_col2 {
#             background-color:  #d8d8ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow18_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow18_col2 {
#             background-color:  #d8d8ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow19_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow19_col2 {
#             background-color:  #d9d9ff;
#             color:  #000000;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow20_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow20_col2 {
#             background-color:  #7676ff;
#             color:  #000000;
#         }</style><table id="T_6002d928_c4d9_11ea_b469_74e6e2e367cf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Zones</th>        <th class="col_heading level0 col1" >w_need_mar [m$^3$]</th>        <th class="col_heading level0 col2" >w_need_verg [m$^3$]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6002d928_c4d9_11ea_b469_74e6e2e367cflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow0_col0" class="data row0 col0" >Zone 7</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow0_col1" class="data row0 col1" >6465.18</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow0_col2" class="data row0 col2" >1.17189e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_6002d928_c4d9_11ea_b469_74e6e2e367cflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow1_col0" class="data row1 col0" >Zone 8</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow1_col1" class="data row1 col1" >88107.1</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow1_col2" class="data row1 col2" >1.07809e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_6002d928_c4d9_11ea_b469_74e6e2e367cflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow2_col0" class="data row2 col0" >Zone 7</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow2_col1" class="data row2 col1" >1969.47</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow2_col2" class="data row2 col2" >236088</td>
#             </tr>
#             <tr>
#                         <th id="T_6002d928_c4d9_11ea_b469_74e6e2e367cflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow3_col0" class="data row3 col0" >Zone 4</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow3_col1" class="data row3 col1" >441208</td>
#                         <td id="T_6002d928_c4d9_11ea_b469_74e6e2e367cfrow3_col2" class="data row3 col2" >2.09373e+06<

# %%
print("Total Water need: {} m3".format(W_need.sum().iloc[0:2].sum()))
print("Calculs de Brli : 30 millions de m3")
# Out:
# Total Water need: 26063115.27 m3
# Calculs de Brli : 30 millions de m3

# %% [markdown]
# Il manque l'intégration de quelques cultures en dehors des shp, ainsi que des prairies

# %%
# sum water need
df = W_need.sum(axis=1).reset_index()
df.columns = ["Zones","Water_need/year"]

# %%
# merge data and get water need in mm/y
data_irrig = pd.merge(zIrr.reset_index(),df.reset_index()).drop("index",axis=1).loc[:,["Zones","Irr_forage","geometry","Surf_Z_Ha","Water_need/year","Irr_can","X_p"]]
data_irrig["Wneed [mm/year]"] = data_irrig.loc[:,"Water_need/year"]/data_irrig.loc[:,"Surf_Z_Ha"]*1e-1
#data_irrig = data_irrig.drop(["Water_need/year","Surf_Z_Ha"],axis=1)

# %%
data_irrig.head()
# Out:
#      Zones  Irr_forage                                           geometry  \
# 0   Zone 7         0.0  POLYGON ((689548.932 6159779.286, 689330.629 6...
# 1   Zone 8         0.8  POLYGON ((702638.710 6164713.007, 702702.478 6...
# 2   Zone 7         0.0  MULTIPOLYGON (((683722.928 6156383.584, 683813...
# 3   Zone 4         0.7  POLYGON ((700069.343 6173529.460, 701428.421 6...
# 4  Zone 2B         0.3  POLYGON ((678247.347 6173329.417, 678248.682 6...
#
#    Surf_Z_Ha  Water_need/year  Irr_can   X_p  Wneed [mm/year]
# 0    1235.03       1178356.43      1.0  0.36        95.411158
# 1    1694.31       1166193.38      0.2  0.32        68.829989
# 2    1227.44        238057.87      1.0  0.00        19.394665
# 3    7033.39       2534934.68      0.0  0.50        36.041435
# 4     799.45       2553289.46      0.7  0.40       319.380757

# %% [markdown]
# #### Calcul des prélèvements agricoles sur la base des besoins en eaux X le mode d'adduction de chaque zone

# %%
#rast quat
file = "../../data/raster/Quat.tif"
Q = resample_rast(file,grid)

# %%
arr_Q = np.zeros([nrow,ncol])
arr_P = np.zeros([nrow,ncol])
for iz in range(data_irrig.shape[0]):
    res = ix.intersect_polygon(data_irrig.geometry[iz])
    for cellid in res.cellids:
        # multiplication du besoin en eau x de la part de forage x de l'aquifère prélevé
        arr_P[cellid[0],cellid[1]] = -data_irrig.loc[iz,"Wneed [mm/year]"]*data_irrig.loc[iz,"Irr_forage"]*(data_irrig.loc[iz,"X_p"])
        if Q[cellid[0],cellid[1]]:
            arr_Q[cellid[0],cellid[1]] = -data_irrig.loc[iz,"Wneed [mm/year]"]*data_irrig.loc[iz,"Irr_forage"]*(1-data_irrig.loc[iz,"X_p"])
        else :
            arr_P[cellid[0],cellid[1]] += -data_irrig.loc[iz,"Wneed [mm/year]"]*data_irrig.loc[iz,"Irr_forage"]*(1-data_irrig.loc[iz,"X_p"])

# %%
arr = np.round(arr_P,decimals=1)
plt.imshow(arr)
plt.colorbar()

# %% [markdown]
# #### Calcul des prélèvements dans la couche sup + dans le pliocène

# %%
def arr2ascii(arr,filename,x0,y0,res,nodata=-9999):
    ncol = arr.shape[1]
    nrow = arr.shape[0]
    with open(filename,"w") as file:
        file.write("ncols {}\n".format(ncol))
        file.write("nrows {}\n".format(nrow))
        file.write("xllcorner {}\n".format(x0))
        file.write("yllcorner {}\n".format(y0))
        file.write("cellsize {}\n".format(res))
        file.write("nodata_value {}\n".format(nodata))
        for irow in range(nrow):
            for icol in range(ncol):
                file.write(str(arr[irow,icol])+" ")

# %%
arr2ascii(arr_Q,"../../data/prélèvements/prlvm_agri_Q.asc",x0,y0,50)
arr2ascii(arr_P,"../../data/prélèvements/prlvm_agri_P.asc",x0,y0,50)

# %%
(arr_Q/1000*50*50).sum()
# Out:
# -10536235.16360562

# %% [markdown]
# #### Calcul des retours nappes des canaux

# %%
coeff = 2 # !!! Coefficient de 2 déjà appliqué donc coeff à définir entre 1 et 2 dans le modèle.

rch_a = np.zeros([nrow,ncol])
for iz in range(data_irrig.shape[0]):
    res = ix.intersect_polygon(data_irrig.geometry[iz])
    for cellid in res.cellids:
        rch_a[cellid[0],cellid[1]] = data_irrig.loc[iz,"Wneed [mm/year]"]*data_irrig.loc[iz,"Irr_can"]*coeff

# %%
rch_a = np.round(rch_a,decimals=1)
plt.imshow(rch_a)
plt.colorbar()

# %%
arr2ascii(rch_a,"../../data/recharge/rast_irr.asc",x0,y0,50)

# %%
(rch_a/1000*50*50).sum()
# Out:
# 17003931.25
