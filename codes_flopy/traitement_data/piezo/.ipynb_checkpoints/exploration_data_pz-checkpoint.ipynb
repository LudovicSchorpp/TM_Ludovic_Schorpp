# %%
import pandas as pd
import geopandas as gp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_pz=pd.read_excel("../../data/chroniques/liste_pz_60_65.xlsx",sheet_name=0)
all_pz
# Out:
#     N°Invent.    X_RGF93_L93   Y_RGF93_L93  Côte margelle  \
# 0          ??  683358.931439  6.178225e+06          70.19
# 1         B10  694569.790049  6.181817e+06          13.85
# 2         B12  694521.925045  6.182088e+06          13.96
# 3         B14  694115.468654  6.181341e+06          16.60
# 4         B15  684819.157323  6.178062e+06          16.46
# ..        ...            ...           ...            ...
# 968       148  688595.956113  6.187041e+06          27.63
# 969       149  688299.331661  6.187494e+06          31.80
# 970      145b  687604.775234  6.188250e+06          38.76
# 971       47b  688394.143430  6.186843e+06            NaN
# 972       60b  692881.366887  6.184704e+06          15.12
#
#      Prof.Pz_étiage_1961  Pz_étiage_1961  \
# 0               1.126667       69.063333
# 1               1.463333       12.386667
# 2               1.890000       12.070000
# 3               3.360000       13.240000
# 4               2.476667       13.983333
# ...

# %%
lst_pz=all_pz.groupby(["X_RGF93_L93","Y_RGF93_L93"]).aggregate({"Pz_étiage_1961":np.mean,
                                                                 "AquifèreCapté":min})
lst_pz.reset_index(inplace=True)
lst_pz.rename(columns={"X_RGF93_L93":"X","Y_RGF93_L93":"Y","Pz_étiage_1961":"Head [m]"},inplace=True)

# %%
fig,ax=plt.subplots(figsize=(10,10))
plt.scatter(lst_pz.X,lst_pz.Y,c=lst_pz["Head [m]"])
plt.colorbar()

# %%
fig,ax=plt.subplots(figsize=(18,5))
lst_pz.AquifèreCapté.hist(ax=ax)

# %%
sns.pairplot(all_pz,hue="AquifèreCapté")
# Out:
# C:\Users\emmal\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\emmal\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\emmal\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\emmal\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
